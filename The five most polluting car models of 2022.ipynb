# %%
import pandas as pd
data = pd.read_csv('ttb.csv')
data
# Out:
#      Model Year          Make                          Model  \
# 0          2022         Acura                            ILX
# 1          2022         Acura                     MDX SH-AWD
# 2          2022         Acura                     RDX SH-AWD
# 3          2022         Acura              RDX SH-AWD A-SPEC
# 4          2022         Acura                     TLX SH-AWD
# 5          2022         Acura              TLX SH-AWD A-SPEC
# 6          2022         Acura                     TLX Type S
# 7          2022         Acura  TLX Type S (Performance Tire)
# 8          2022    Alfa Romeo                         Giulia
# 9          2022    Alfa Romeo                     Giulia AWD
# 10         2022    Alfa Romeo            Giulia Quadrifoglio
# 11         2022    Alfa Romeo                        Stelvio
# 12         2022    Alfa Romeo                    Stelvio AWD
# 13         2022    Alfa Romeo       Stelvio AWD Quadrifoglio
# ...

# %%
pollution=data['CO2 Emissions(g/km)']
vclass=data['Vehicle Class']
cyl=data['Cylinders']
engine=data['Engine Size(L)']
pollutest = data[data['CO2 Emissions(g/km)']>400]
print(contamination.max(),engine.max())
# Out:
# 608 8.0

# %%
#The five most polluting models

# %%
import matplotlib.pyplot as plt
#plt.scatter(engine, contamination)
plt.scatter(pollutest['Fuel Consumption(Comb (L/100 km))'], pollutest['CO2 Emissions(g/km)'])
for k,row in pollutest.iterrows():
    plt.text(row['Fuel Consumption(Comb (L/100 km))'], row['CO2 Emissions(g/km)'], row['Make'])
plt.xlabel('Fuel Consumption')
plt.ylabel('Pollution')
# Out:
# Text(0,0.5,'Pollution')
